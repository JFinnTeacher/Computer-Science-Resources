# %% [markdown]
# # Lesson 02 Variables and Datatypes

# %% [markdown]
# ## Introduction to Variables

# %% [markdown]
# **Exercise 1:**
# - Define a variable `name` and assign your name to it.
# - Define a variable `age` and assign your age to it.
# - Define a variable `height` and assign your height in meters to it.
# - Print all three variables.

# %%
name = "Mr Finn"
age = 21
height = 1.75
print(name)
print(age)
print(height)
# Out:
# Mr Finn
# 21
# 1.75

# %% [markdown]
# **Exercise 2:**
# - Define a variable `message` and assign a greeting message to it.
# - Print the `message` variable.

# %%
message = "Hello All"

# %% [markdown]
# ## Datatypes

# %% [markdown]
# **Exercise 3:**
# - Define a variable `is_student` and assign a boolean value to it indicating whether you are a student.
# - Print the datatype of `is_student`.

# %%
is_student = True
print(is_student)

# %% [markdown]
# **Exercise 4:**
# - Define a variable `pi` and assign the value 3.14159 to it.
# - Print the datatype of `pi`.

# %%
pi = (3.14159)
print(pi)
# Out:
# 3.14159

# %% [markdown]
# ## Store Data in Variables and Print Them Out

# %% [markdown]
# **Exercise 5:**
# - Define a variable `favorite_color` and assign your favorite color to it.
# - Define a variable `favorite_number` and assign your favorite number to it.
# - Print a sentence that uses both variables.

# %%
favourite_color = "Black"
favourite_number = 42
print("My favourite colour is", favourite_color, " and the answer to life the universe and everything is ", favourite_number)
# Out:
# My favourite colour is Black  and the answer to life the universe and everything is  42

# %% [markdown]
# ## Rules for Naming Variables

# %% [markdown]
# **Exercise 6:**
# - Define a variable using an appropriate name to store the number of siblings you have.
# - Define another variable to store the city you live in.
# - Print both variables.

# %%
NoSiblings = 4
MyCity = "Dublin"
print("I have ",NoSiblings, "siblings and I live in ",MyCity)
# Out:
# I have  4 siblings and I live in  Dublin

# %% [markdown]
# ## Operators

# %% [markdown]
# **Exercise 7:**
# - Define two variables `x` and `y`, and assign them the values 10 and 5 respectively.
# - Perform the following operations and print the results:
#   - Addition
#   - Subtraction
#   - Multiplication
#   - Division

# %%
x = 10
y = 5
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# **Exercise 8:**
# - Define a variable `number` and assign the value 15 to it.
# - Use the modulo operator to check if `number` is even or odd and print the result.

# %%
number = 15
print("When you divide by 2 an even number will have a remainder of 0")
print("The remainder from your number is", number % 2)
# Out:
# When you divide by 2 an even number will have a remainder of 0
# The remainder from your number is 1

# %% [markdown]
# ## PEMDAS

# %% [markdown]
# **Exercise 10:**
# - Calculate the result of the following expression and print the result:
#   - $7 + 3 * (2 ** 3) - (4 / 2)$

# %%
answer = 7+3*(2**3)-(4/2)
print("The answer of 7+3*(2**3)-(4/2) is" ,answer)
# Out:
# The answer of 7+3*(2**3)-(4/2) is 29.0
