# %% [markdown]
# # Python Exercises
# These exercises are designed to help you practice using basic Python commands and string manipulations.

# %% [markdown]
# ## Exercise 1: Using input command and declaring Data Type

# %% [markdown]
# ### Exercise 1.1
# Write a program that takes a user's name as input and prints a greeting message.
# ```
# Example Output
# Enter your name: John
# Hello, John!
# ```

# %% [markdown]
# ### Exercise 1.2
# Write a program that takes two numbers as input, converts them to integers, and prints their sum.
# ```
# Example Output
# Enter first number: 5
# Enter second number: 3
# Sum: 8
# ```

# %% [markdown]
# ## Exercise 2: Adding and Multiplying Strings

# %% [markdown]
# ### Exercise 2.1
# Write a program that takes a string as input and prints the string repeated three times.
# ```
# Example Output
# Enter a string: hello
# hellohellohello
# ```

# %% [markdown]
# ### Exercise 2.2
# Write a program that takes two strings as input and prints them concatenated with a space in between.
# ```python
# Example Output
# Enter first string: hello
# Enter second string: world
# hello world
# ```

# %% [markdown]
# ## Exercise 3: Changing the case of a string

# %% [markdown]
# ### Exercise 3.1
# Write a program that takes a string as input and prints it in uppercase.
# ```
# Example Output
# Enter a string: hello
# HELLO
# ```

# %% [markdown]
# ### Exercise 3.2
# Write a program that takes a string as input and prints it in lowercase.
# ```
# Example Output
# Enter a string: HELLO
# hello
# ```

# %% [markdown]
# ## Exercise 4: Counting the length of a string

# %% [markdown]
# ### Exercise 4.1
# Write a program that takes a string as input and prints the number of characters in the string.
# ```
# Example Output
# Enter a string: hello
# Length: 5
# ```

# %% [markdown]
# ## Exercise 5: String Concatenation

# %% [markdown]
# ### Exercise 5.1
# Write a program that takes the first name and last name as input and prints the full name.
# ```
# Example Output
# Enter first name: John
# Enter last name: Doe
# Full name: John Doe
# ```

# %% [markdown]
# ### Exercise 5.2
# Write a program that takes three words as input and prints them concatenated with a hyphen between each word.
# ```
# Example Output
# Enter first word: hello
# Enter second word: world
# Enter third word: python
# hello-world-python
# ```
